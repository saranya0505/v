# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn

# %%
dataset=pd.read_csv("Churn_Modelling.csv")

# %%
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
dataset.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %%
dataset.shape
# Out:
# (10000, 14)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# ## STATISTICAL ANALAYSIS

# %%
dataset.mean()
# Out:
# C:\Users\balas\AppData\Local\Temp\ipykernel_10640\1799472221.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dataset.mean()
# RowNumber          5.000500e+03
# CustomerId         1.569094e+07
# CreditScore        6.505288e+02
# Age                3.892180e+01
# Tenure             5.012800e+00
# Balance            7.648589e+04
# NumOfProducts      1.530200e+00
# HasCrCard          7.055000e-01
# IsActiveMember     5.151000e-01
# EstimatedSalary    1.000902e+05
# Exited             2.037000e-01
# dtype: float64

# %%
dataset.median()
# Out:
# C:\Users\balas\AppData\Local\Temp\ipykernel_10640\4167803218.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dataset.median()
# RowNumber          5.000500e+03
# CustomerId         1.569074e+07
# CreditScore        6.520000e+02
# Age                3.700000e+01
# Tenure             5.000000e+00
# Balance            9.719854e+04
# NumOfProducts      1.000000e+00
# HasCrCard          1.000000e+00
# IsActiveMember     1.000000e+00
# EstimatedSalary    1.001939e+05
# Exited             0.000000e+00
# dtype: float64

# %%
dataset.mode()
# Out:
#       RowNumber  CustomerId Surname  CreditScore Geography Gender   Age  \
# 0             1    15565701   Smith        850.0    France   Male  37.0
# 1             2    15565706     NaN          NaN       NaN    NaN   NaN
# 2             3    15565714     NaN          NaN       NaN    NaN   NaN
# 3             4    15565779     NaN          NaN       NaN    NaN   NaN
# 4             5    15565796     NaN          NaN       NaN    NaN   NaN
# ...         ...         ...     ...          ...       ...    ...   ...
# 9995       9996    15815628     NaN          NaN       NaN    NaN   NaN
# 9996       9997    15815645     NaN          NaN       NaN    NaN   NaN
# 9997       9998    15815656     NaN          NaN       NaN    NaN   NaN
# 9998       9999    15815660     NaN          NaN       NaN    NaN   NaN
# 9999      10000    15815690     NaN          NaN       NaN    NaN   NaN
#
#       Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
dataset.var()
# Out:
# C:\Users\balas\AppData\Local\Temp\ipykernel_10640\2458428038.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dataset.var()
# RowNumber          8.334167e+06
# CustomerId         5.174815e+09
# CreditScore        9.341860e+03
# Age                1.099941e+02
# Tenure             8.364673e+00
# Balance            3.893436e+09
# NumOfProducts      3.383218e-01
# HasCrCard          2.077905e-01
# IsActiveMember     2.497970e-01
# EstimatedSalary    3.307457e+09
# Exited             1.622225e-01
# dtype: float64

# %%
dataset.std()
# Out:
# C:\Users\balas\AppData\Local\Temp\ipykernel_10640\178401259.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dataset.std()
# RowNumber           2886.895680
# CustomerId         71936.186123
# CreditScore           96.653299
# Age                   10.487806
# Tenure                 2.892174
# Balance            62397.405202
# NumOfProducts          0.581654
# HasCrCard              0.455840
# IsActiveMember         0.499797
# EstimatedSalary    57510.492818
# Exited                 0.402769
# dtype: float64

# %%
dataset.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
dataset['Age'].unique ()
# Out:
# array([42, 41, 39, 43, 44, 50, 29, 27, 31, 24, 34, 25, 35, 45, 58, 32, 38,
#        46, 36, 33, 40, 51, 61, 49, 37, 19, 66, 56, 26, 21, 55, 75, 22, 30,
#        28, 65, 48, 52, 57, 73, 47, 54, 72, 20, 67, 79, 62, 53, 80, 59, 68,
#        23, 60, 70, 63, 64, 18, 82, 69, 74, 71, 76, 77, 88, 85, 84, 78, 81,
#        92, 83], dtype=int64)

# %%
dataset['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
dataset['Age'].value_counts ()
# Out:
# 37    478
# 38    477
# 35    474
# 36    456
# 34    447
#      ...
# 92      2
# 82      1
# 88      1
# 85      1
# 83      1
# Name: Age, Length: 70, dtype: int64

# %% [markdown]
# ## DataVisualization
# 1.Uni Variate Analysis
#
# 2.Bi Variate Analysis
#
# 3.Multi Variate Analysis

# %% [markdown]
# ### Uni Variate Analysis

# %%
sns.distplot(dataset['Age'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.histplot(dataset['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.boxplot(dataset['Age'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
sns.distplot(dataset['RowNumber'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='RowNumber', ylabel='Density'>

# %%
sns.histplot(dataset['RowNumber'])
# Out:
# <AxesSubplot:xlabel='RowNumber', ylabel='Count'>

# %%
sns.boxplot(dataset['RowNumber'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='RowNumber'>

# %%
sns.distplot(dataset['CustomerId'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CustomerId', ylabel='Density'>

# %%
sns.histplot(dataset['CustomerId'])
# Out:
# <AxesSubplot:xlabel='CustomerId', ylabel='Count'>

# %%
sns.boxplot(dataset['CustomerId'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='CustomerId'>

# %%
sns.distplot(dataset['CreditScore'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CreditScore', ylabel='Density'>

# %%
sns.histplot(dataset['CreditScore'])
# Out:
# <AxesSubplot:xlabel='CreditScore', ylabel='Count'>

# %%
sns.boxplot(dataset['CreditScore'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='CreditScore'>

# %%
sns.distplot(dataset['Tenure'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Tenure', ylabel='Density'>

# %%
sns.histplot(dataset['Tenure'])
# Out:
# <AxesSubplot:xlabel='Tenure', ylabel='Count'>

# %%
sns.boxplot(dataset['Tenure'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Tenure'>

# %%
sns.distplot(dataset['Balance'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Balance', ylabel='Density'>

# %%
sns.histplot(dataset['Balance'])
# Out:
# <AxesSubplot:xlabel='Balance', ylabel='Count'>

# %%
sns.boxplot(dataset['Balance'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Balance'>

# %%
sns.distplot(dataset['NumOfProducts'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='NumOfProducts', ylabel='Density'>

# %%
sns.histplot(dataset['NumOfProducts'])
# Out:
# <AxesSubplot:xlabel='NumOfProducts', ylabel='Count'>

# %%
sns.boxplot(dataset['NumOfProducts'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='NumOfProducts'>

# %%
sns.distplot(dataset['HasCrCard'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='HasCrCard', ylabel='Density'>

# %%
sns.histplot(dataset['HasCrCard'])
# Out:
# <AxesSubplot:xlabel='HasCrCard', ylabel='Count'>

# %%
sns.boxplot(dataset['HasCrCard'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='HasCrCard'>

# %%
sns.distplot(dataset['IsActiveMember'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='IsActiveMember', ylabel='Density'>

# %%
sns.histplot(dataset['IsActiveMember'])
# Out:
# <AxesSubplot:xlabel='IsActiveMember', ylabel='Count'>

# %%
sns.boxplot(dataset['IsActiveMember'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='IsActiveMember'>

# %%
sns.distplot(dataset['EstimatedSalary'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='EstimatedSalary', ylabel='Density'>

# %%
sns.histplot(dataset['EstimatedSalary'])
# Out:
# <AxesSubplot:xlabel='EstimatedSalary', ylabel='Count'>

# %%
sns.boxplot(dataset['EstimatedSalary'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='EstimatedSalary'>

# %%
sns.distplot(dataset['Exited'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Exited', ylabel='Density'>

# %%
sns.histplot(dataset['Exited'])
# Out:
# <AxesSubplot:xlabel='Exited', ylabel='Count'>

# %%
sns.boxplot(dataset['Exited'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Exited'>

# %% [markdown]
# ## Bi Variate Analysis

# %%
sns.lineplot(dataset['Age'], dataset['Balance'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Balance'>

# %%
plt.figure(figsize=(50,50))
sns.barplot(dataset['Age'], dataset['Balance'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Balance'>

# %%
sns.scatterplot(dataset['Age'], dataset['Balance'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Balance'>

# %%
sns.lineplot(dataset['Age'], dataset['Tenure'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Tenure'>

# %%
sns.barplot(dataset['Age'], dataset['Tenure'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Tenure'>

# %%
sns.scatterplot(dataset['Age'], dataset['Tenure'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Tenure'>

# %%
sns.lineplot(dataset['Age'], dataset['CreditScore'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='CreditScore'>

# %%
sns.barplot(dataset['Age'], dataset['CreditScore'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='CreditScore'>

# %%
sns.scatterplot(dataset['Age'], dataset['CreditScore'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='CreditScore'>

# %%
sns.lineplot(dataset['Age'], dataset['EstimatedSalary'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='EstimatedSalary'>

# %%
sns.barplot(dataset['Age'], dataset['EstimatedSalary'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='EstimatedSalary'>

# %%
sns.scatterplot(dataset['Age'], dataset['EstimatedSalary'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='EstimatedSalary'>

# %% [markdown]
# ## Multi Variate Analysis

# %%
sns.lineplot(dataset['Age'], dataset['EstimatedSalary'], hue = dataset['Gender'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='EstimatedSalary'>

# %%
sns.barplot(dataset['Age'], dataset['EstimatedSalary'], hue = dataset['Gender'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='EstimatedSalary'>

# %%
sns.scatterplot(dataset['Age'], dataset['EstimatedSalary'], hue = dataset['Gender'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='EstimatedSalary'>

# %%
sns.lineplot(dataset['Age'], dataset['Tenure'], hue = dataset['CreditScore'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Tenure'>

# %%
sns.pairplot(dataset)

# %%
dataset.corr()
# Out:
#                  RowNumber  CustomerId  CreditScore       Age    Tenure  \
# RowNumber         1.000000    0.004202     0.005840  0.000783 -0.006495
# CustomerId        0.004202    1.000000     0.005308  0.009497 -0.014883
# CreditScore       0.005840    0.005308     1.000000 -0.003965  0.000842
# Age               0.000783    0.009497    -0.003965  1.000000 -0.009997
# Tenure           -0.006495   -0.014883     0.000842 -0.009997  1.000000
# Balance          -0.009067   -0.012419     0.006268  0.028308 -0.012254
# NumOfProducts     0.007246    0.016972     0.012238 -0.030680  0.013444
# HasCrCard         0.000599   -0.014025    -0.005458 -0.011721  0.022583
# IsActiveMember    0.012044    0.001665     0.025651  0.085472 -0.028362
# EstimatedSalary  -0.005988    0.015271    -0.001384 -0.007201  0.007784
# Exited           -0.016571   -0.006248    -0.027094  0.285323 -0.014001
#
#                   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
sns.heatmap(dataset.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Handling The Missing Values

# %%
dataset.isnull().any()
# Out:
# RowNumber          False
# CustomerId         False
# Surname            False
# CreditScore        False
# Geography          False
# Gender             False
# Age                False
# Tenure             False
# Balance            False
# NumOfProducts      False
# HasCrCard          False
# IsActiveMember     False
# EstimatedSalary    False
# Exited             False
# dtype: bool

# %%
dataset.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
dataset.mode()
# Out:
#       RowNumber  CustomerId Surname  CreditScore Geography Gender   Age  \
# 0             1    15565701   Smith        850.0    France   Male  37.0
# 1             2    15565706     NaN          NaN       NaN    NaN   NaN
# 2             3    15565714     NaN          NaN       NaN    NaN   NaN
# 3             4    15565779     NaN          NaN       NaN    NaN   NaN
# 4             5    15565796     NaN          NaN       NaN    NaN   NaN
# ...         ...         ...     ...          ...       ...    ...   ...
# 9995       9996    15815628     NaN          NaN       NaN    NaN   NaN
# 9996       9997    15815645     NaN          NaN       NaN    NaN   NaN
# 9997       9998    15815656     NaN          NaN       NaN    NaN   NaN
# 9998       9999    15815660     NaN          NaN       NaN    NaN   NaN
# 9999      10000    15815690     NaN          NaN       NaN    NaN   NaN
#
#       Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
dataset['Age'].unique()
# Out:
# array([42, 41, 39, 43, 44, 50, 29, 27, 31, 24, 34, 25, 35, 45, 58, 32, 38,
#        46, 36, 33, 40, 51, 61, 49, 37, 19, 66, 56, 26, 21, 55, 75, 22, 30,
#        28, 65, 48, 52, 57, 73, 47, 54, 72, 20, 67, 79, 62, 53, 80, 59, 68,
#        23, 60, 70, 63, 64, 18, 82, 69, 74, 71, 76, 77, 88, 85, 84, 78, 81,
#        92, 83], dtype=int64)

# %%
dataset['Age'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       42
# 1       41
# 2       42
# 3       39
# 4       43
#         ..
# 9995    39
# 9996    35
# 9997    36
# 9998    42
# 9999    28
# Name: Age, Length: 10000, dtype: int64>

# %%
# replacing the null values 
dataset['Age'] = dataset['Age'].fillna(dataset['Age'].median())

# %% [markdown]
# ## Find and Replace Outliers

# %%
dataset.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
sns.boxplot(dataset['Age'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
dataset['Age'],dataset['NumOfProducts'].unique()
# Out:
# (0       42
#  1       41
#  2       42
#  3       39
#  4       43
#          ..
#  9995    39
#  9996    35
#  9997    36
#  9998    42
#  9999    28
#  Name: Age, Length: 10000, dtype: int64,
#  array([1, 3, 2, 4], dtype=int64))

# %%
q = dataset.quantile([0.75,0.50])

# %%
q
# Out:
#       RowNumber   CustomerId  CreditScore   Age  Tenure    Balance  \
# 0.75    7500.25  15753233.75        718.0  44.0     7.0  127644.24
# 0.50    5000.50  15690738.00        652.0  37.0     5.0   97198.54
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0.75            2.0        1.0             1.0      149388.2475     0.0
# 0.50            1.0        1.0             1.0      100193.9150     0.0

# %%
iqr = q.iloc[0] - q.iloc[1]

# %%
iqr
# Out:
# RowNumber           2499.7500
# CustomerId         62495.7500
# CreditScore           66.0000
# Age                    7.0000
# Tenure                 2.0000
# Balance            30445.7000
# NumOfProducts          1.0000
# HasCrCard              0.0000
# IsActiveMember         0.0000
# EstimatedSalary    49194.3325
# Exited                 0.0000
# dtype: float64

# %%
u = q.iloc[0] + (1.5*iqr) # q3 + 1.5*iqr

# %%
u
# Out:
# RowNumber          1.124988e+04
# CustomerId         1.584698e+07
# CreditScore        8.170000e+02
# Age                5.450000e+01
# Tenure             1.000000e+01
# Balance            1.733128e+05
# NumOfProducts      3.500000e+00
# HasCrCard          1.000000e+00
# IsActiveMember     1.000000e+00
# EstimatedSalary    2.231797e+05
# Exited             0.000000e+00
# dtype: float64

# %%
l = q.iloc[1] - (1.5*iqr)

# %%
l
# Out:
# RowNumber          1.250875e+03
# CustomerId         1.559699e+07
# CreditScore        5.530000e+02
# Age                2.650000e+01
# Tenure             2.000000e+00
# Balance            5.152999e+04
# NumOfProducts     -5.000000e-01
# HasCrCard          1.000000e+00
# IsActiveMember     1.000000e+00
# EstimatedSalary    2.640242e+04
# Exited             0.000000e+00
# dtype: float64

# %%
## handling outliers

dataset['Age'] = np.where(dataset['Age']>5,4,dataset['Age'])

# %%
sns.boxplot(dataset['Age'])
# Out:
# C:\Users\balas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# ##  Check for Categorical columns and perform encoding.

# %%
# converting categorical values into numericalvalues - Encoding

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
le = LabelEncoder()
oneh = OneHotEncoder()
dataset['Gender'] = le.fit_transform(dataset['Gender'])

# %%
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France       0    4
# 1          2    15647311      Hill          608     Spain       0    4
# 2          3    15619304      Onio          502    France       0    4
# 3          4    15701354      Boni          699    France       0    4
# 4          5    15737888  Mitchell          850     Spain       0    4
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
dataset['CreditScore'] = le.fit_transform(dataset['CreditScore'])

# %%
dataset.head()
# Out:
#    RowNumber  CustomerId  Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0          1    15634602     1115          228    France       0    4       2
# 1          2    15647311     1177          217     Spain       0    4       1
# 2          3    15619304     2040          111    France       0    4       8
# 3          4    15701354      289          308    France       0    4       1
# 4          5    15737888     1822          459     Spain       0    4       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# ...

# %%
dataset['Surname'] = le.fit_transform(dataset['Surname'])

# %%
dataset.head()
# Out:
#    RowNumber  CustomerId  Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0          1    15634602     1115          228    France       0    4       2
# 1          2    15647311     1177          217     Spain       0    4       1
# 2          3    15619304     2040          111    France       0    4       8
# 3          4    15701354      289          308    France       0    4       1
# 4          5    15737888     1822          459     Spain       0    4       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# ...

# %%
dataset['Geography'] = le.fit_transform(dataset['Geography'])

# %%
dataset.head()
# Out:
#    RowNumber  CustomerId  Surname  CreditScore  Geography  Gender  Age  \
# 0          1    15634602     1115          228          0       0    4
# 1          2    15647311     1177          217          2       0    4
# 2          3    15619304     2040          111          0       0    4
# 3          4    15701354      289          308          0       0    4
# 4          5    15737888     1822          459          2       0    4
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
dataset['CustomerId'] = le.fit_transform(dataset['CustomerId'])

# %%
dataset.head()
# Out:
#    RowNumber  CustomerId  Surname  CreditScore  Geography  Gender  Age  \
# 0          1        2736     1115          228          0       0    4
# 1          2        3258     1177          217          2       0    4
# 2          3        2104     2040          111          0       0    4
# 3          4        5435      289          308          0       0    4
# 4          5        6899     1822          459          2       0    4
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %% [markdown]
# dataset['NumOfProducts'] = le.fit_transform(dataset['NumOfProducts'])

# %%
dataset.head()
# Out:
#    RowNumber  CustomerId  Surname  CreditScore  Geography  Gender  Age  \
# 0          1        2736     1115          228          0       0    4
# 1          2        3258     1177          217          2       0    4
# 2          3        2104     2040          111          0       0    4
# 3          4        5435      289          308          0       0    4
# 4          5        6899     1822          459          2       0    4
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              0          1               1
# 1       1   83807.86              0          0               1
# 2       8  159660.80              2          1               0
# 3       1       0.00              1          0               0
# 4       2  125510.82              0          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %% [markdown]
# ## Split the data into dependent and independent variables

# %%
x = dataset.iloc[:, 0:13]

# %%
x #independent values (inputs)
# Out:
#       RowNumber  CustomerId  Surname  CreditScore  Geography  Gender  Age  \
# 0             1        2736     1115          228          0       0    4
# 1             2        3258     1177          217          2       0    4
# 2             3        2104     2040          111          0       0    4
# 3             4        5435      289          308          0       0    4
# 4             5        6899     1822          459          2       0    4
# ...         ...         ...      ...          ...        ...     ...  ...
# 9995       9996        1599     1999          380          0       1    4
# 9996       9997         161     1336          125          0       1    4
# 9997       9998         717     1570          318          0       0    4
# 9998       9999        4656     2345          381          1       1    4
# 9999      10000        2497     2751          401          0       0    4
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
y = dataset['Exited']

# %%
y # dependent values (output)
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %% [markdown]
# ## Scale the independent variables

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
sc = StandardScaler()
x_scaled = sc.fit_transform(x)

# %%
x_scaled
# Out:
# array([[-1.73187761, -0.7840994 , -0.46418322, ...,  0.64609167,
#          0.97024255,  0.02188649],
#        [-1.7315312 , -0.6032733 , -0.3909112 , ..., -1.54776799,
#          0.97024255,  0.21653375],
#        [-1.73118479, -1.00303063,  0.62898807, ...,  0.64609167,
#         -1.03067011,  0.2406869 ],
#        ...,
#        [ 1.73118479, -1.48350152,  0.07353887, ..., -1.54776799,
#          0.97024255, -1.00864308],
#        [ 1.7315312 , -0.11899189,  0.98943914, ...,  0.64609167,
#         -1.03067011, -0.12523071],
#        [ 1.73187761, -0.86689143,  1.4692527 , ...,  0.64609167,
#         -1.03067011, -1.07636976]])

# %% [markdown]
# ## Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split (x_scaled, y, test_size = 0.3, random_state = 0)

# %%
x_train
# Out:
# array([[ 0.92889885, -0.79726299, -1.47580983, ...,  0.64609167,
#          0.97024255, -0.77021814],
#        [ 1.39655257,  0.7123925 , -1.58808148, ...,  0.64609167,
#         -1.03067011, -1.39576675],
#        [-0.4532777 ,  0.96076859, -0.24082173, ..., -1.54776799,
#          0.97024255, -1.49965629],
#        ...,
#        [-0.60119484, -1.61652303, -0.36136603, ...,  0.64609167,
#         -1.03067011,  1.41441489],
#        [ 1.67853045, -0.374989  ,  0.72589622, ...,  0.64609167,
#          0.97024255,  0.84614739],
#        [-0.78548505, -1.36121874,  1.3829808 , ...,  0.64609167,
#         -1.03067011,  0.32630495]])

# %%
x_test
# Out:
# array([[ 1.52229946, -1.04737113,  1.39834429, ...,  0.64609167,
#          0.97024255,  1.61304597],
#        [-1.42080128, -0.5080105 , -0.78208925, ...,  0.64609167,
#         -1.03067011,  0.49753166],
#        [-0.90118604, -0.79275966,  0.41271742, ...,  0.64609167,
#          0.97024255, -0.4235611 ],
#        ...,
#        [ 1.49216178, -0.14531906,  0.6868966 , ...,  0.64609167,
#          0.97024255,  1.17045451],
#        [ 1.1758893 , -1.2919367 , -1.38481071, ...,  0.64609167,
#          0.97024255, -0.50846777],
#        [ 0.08088677, -1.3837354 ,  1.11707427, ...,  0.64609167,
#          0.97024255, -1.15342685]])

# %%
x_test.shape
# Out:
# (3000, 13)

# %%
y_train
# Out:
# 7681    1
# 9031    0
# 3691    0
# 202     1
# 5625    0
#        ..
# 9225    0
# 4859    0
# 3264    0
# 9845    0
# 2732    1
# Name: Exited, Length: 7000, dtype: int64

# %%
y_train.shape
# Out:
# (7000,)

# %%
y_test
# Out:
# 9394    0
# 898     1
# 2398    0
# 5906    0
# 2343    0
#        ..
# 4004    0
# 7375    0
# 9307    0
# 8394    0
# 5233    1
# Name: Exited, Length: 3000, dtype: int64

# %%
y_test.shape
# Out:
# (3000,)
